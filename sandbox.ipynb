# %%
from livesplit_parser.livesplit_data import LivesplitData
from livesplit_parser.runner_data import RunnerData

frobuddy = LivesplitData('frobuddy_sm64_16star.lss', time_key="RealTime")
super64guy = LivesplitData('super64guy_sm64_16star.lss', time_key="RealTime")
frobad = LivesplitData('frobuddyoldsplits.lss', time_key="RealTime")
test_dict = RunnerData({'frobuddy':frobuddy, 'super64guy':super64guy})
test_dict.add_runner_data('frobad', frobad)
#test_dict = RunnerData({'super64guy':super64guy, 'frobuddy':frobuddy})

test_dict.plot_percent_past(True)

#frobuddy.plot_completed_runs_lineplot()
# Out:
# ERROR: User frobad does not match split layout of other splits. Please adjust the split file in LiveSplit to match.
# alt.Chart(...)

# %%
import pandas as pd

df = pd.DataFrame({
    'Name': ['John', 'Bob', 'Shiela'],
    'Course': ['Masters', 'Graduate', 'Graduate'],
    'Age': [27, 23, 21]
})

print(df)

melted_df = pd.melt(df, id_vars=['Name'], value_vars=['Course', 'Age'])


print(melted_df)
# Out:
#      Name    Course  Age
# 0    John   Masters   27
# 1     Bob  Graduate   23
# 2  Shiela  Graduate   21
#      Name variable     value
# 0    John   Course   Masters
# 1     Bob   Course  Graduate
# 2  Shiela   Course  Graduate
# 3    John      Age        27
# 4     Bob      Age        23
# 5  Shiela      Age        21
