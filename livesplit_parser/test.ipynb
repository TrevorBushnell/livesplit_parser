# %%
import importlib
import livesplit_data

importlib.reload(livesplit_data)

splits = livesplit_data.LivesplitData.read_lss('./../super64guy_sm64_16star.lss')
splits.plot_num_resets()
# Out:
# alt.Chart(...)
